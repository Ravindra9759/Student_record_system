# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize,sent_tokenize
from collections import Counter 
import string


nltk.download("punkt")
nltk.download("stopwords")

paragraph = input("Enter a paragraph : ")

sentences = word_tokenize(paragraph)

word = word_tokenize(paragraph.lower())

stop_words = set(stopwords.words("english"))
filtered_words = [w for w in words if w not in stop_words and w not in string.punctuation ]

word_count = len(filtered_words)

freq_words = Counter(filtered_words).most_common(5)

sentence_lengths = [len(word_tokenize(s)) for s in sentences]
avg_len = sum(sentence_lengths) / len(sentence_lengths)
min_len = min(sentence_lengths)
max_len = max(sentence_lengths)

with open("results_nltk.txt", "w") as f:
    f.write(f"Word Count : {word_count}\n")
    f.write(f"Top 5 Frequent Words : \n")
    for word,freq in freq_words:
        f.write(f"{word} : {freq}\n")
    f.write(f"\nSentence Lengths : {sentence_lengths}\n")
    f.write(f"Average Lenght : {avg_len :.2f}, Min : {min_len}, Max : {max_len}\n")
print("Analysis complete ! Results saved to results_nltk.txt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\1990p\AppData\Roaming\nltk_data...
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[1], line 8
#       4 from collections import Counter
#       5 import string
# ----> 8 nltk.download("punkt")
#       9 nltk.download("stopwords")
#      11 paragraph = input("Enter a paragraph : ")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\nltk\downloader.py:762, in Downloader.download(self, info_or_id, download_dir, quiet, force, prefix, halt_on_error, raise_on_error, print_error_to)
#     753 def show(s, prefix2=""):
#     754     print_to(
#     755         textwrap.fill(
#     756             s,
#    (...)    759         )
#     760     )
# --> 762 for msg in self.incr_download(info_or_id, download_dir, force):
#     763     # Error messages
# ...
